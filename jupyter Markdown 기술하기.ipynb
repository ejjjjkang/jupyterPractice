# %% [markdown]
# #이것은 표제이다.
#
# 이것은 단락이다.
#
# -조항 쓰기도 이렇게 표현할 수 있다.
# 테이블도 기술할 수 있다.
#
# package | version
# --------| --------
# pandas  | 0.19.2
# matplotlib| 2.0.0

# %% [markdown]
# ##수식 표시
#
# 이 코드 셀에는 다음과 같이 서식을 표현할 수 있다.
#
# \begin{align}
# \sqrt{2x-1}+(3+x)^3$
# \end{align}
#
# $$ E = mc^2 $$
#
# 인라인에서도 오른쪽에 쓰여진 것처럼 $\sqrt{a^2+b^2}$를 기술할 수 있다.

# %% [markdown]
# ## Jupyter 기동 후 홈 화면이다
#
# ![jupyter-home.jpg](attachment:jupyter-home.jpg)
